# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('amazon_delivery.csv')

# %%
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df = df.drop('Order_ID',axis=1)

# %%
df.head()
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# 1         34           4.5       12.913041        77.683237      13.043041
# 2         23           4.4       12.914264        77.678400      12.924264
# 3         38           4.7       11.003669        76.976494      11.053669
# 4         32           4.6       12.972793        80.249982      13.012793
#
#    Drop_Longitude  Order_Date Order_Time Pickup_Time     Weather  Traffic  \
# 0       75.912471  2022-03-19   11:30:00    11:45:00       Sunny    High
# 1       77.813237  2022-03-25   19:45:00    19:50:00      Stormy     Jam
# 2       77.688400  2022-03-19   08:30:00    08:45:00  Sandstorms     Low
# 3       77.026494  2022-04-05   18:00:00    18:10:00       Sunny  Medium
# 4       80.289982  2022-03-26   13:30:00    13:45:00      Cloudy    High
#
#        Vehicle            Area  Delivery_Time     Category
# ...

# %%
df.shape
# Out:
# (43739, 15)

# %%
unecessary_features = ['Order_Time','Pickup_Time']

# %%
df = df.drop(unecessary_features,axis=1)

# %%
df.shape
# Out:
# (43739, 13)

# %%
df['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df['Category'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head()
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# 1         34           4.5       12.913041        77.683237      13.043041
# 2         23           4.4       12.914264        77.678400      12.924264
# 3         38           4.7       11.003669        76.976494      11.053669
# 4         32           4.6       12.972793        80.249982      13.012793
#
#    Drop_Longitude  Order_Date     Weather  Traffic      Vehicle  \
# 0       75.912471  2022-03-19       Sunny    High   motorcycle
# 1       77.813237  2022-03-25      Stormy     Jam      scooter
# 2       77.688400  2022-03-19  Sandstorms     Low   motorcycle
# 3       77.026494  2022-04-05       Sunny  Medium   motorcycle
# 4       80.289982  2022-03-26      Cloudy    High      scooter
#
#              Area  Delivery_Time     Category
# 0          Urban             120     Clothing
# ...

# %%
df['Weather'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Weather'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Weather'>

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Fog           7440
# Stormy        7374
# Cloudy        7288
# Sandstorms    7245
# Windy         7223
# Sunny         7078
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (43739, 13)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Weather'] = le.fit_transform(df['Weather'])

# %%
df.head()
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# 1         34           4.5       12.913041        77.683237      13.043041
# 2         23           4.4       12.914264        77.678400      12.924264
# 3         38           4.7       11.003669        76.976494      11.053669
# 4         32           4.6       12.972793        80.249982      13.012793
#
#    Drop_Longitude  Order_Date  Weather  Traffic      Vehicle            Area  \
# 0       75.912471  2022-03-19        4    High   motorcycle           Urban
# 1       77.813237  2022-03-25        3     Jam      scooter   Metropolitian
# 2       77.688400  2022-03-19        2     Low   motorcycle           Urban
# 3       77.026494  2022-04-05        4  Medium   motorcycle   Metropolitian
# 4       80.289982  2022-03-26        0    High      scooter   Metropolitian
#
#    Delivery_Time     Category
# ...

# %%
df['Area'] = le.fit_transform(df['Area'])

# %%
df['Traffic'] = le.fit_transform(df['Traffic'])

# %%
df['Vehicle'] = le.fit_transform(df['Vehicle'])

# %%
df.head()
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# 1         34           4.5       12.913041        77.683237      13.043041
# 2         23           4.4       12.914264        77.678400      12.924264
# 3         38           4.7       11.003669        76.976494      11.053669
# 4         32           4.6       12.972793        80.249982      13.012793
#
#    Drop_Longitude  Order_Date  Weather  Traffic  Vehicle  Area  Delivery_Time  \
# 0       75.912471  2022-03-19        4        0        1     3            120
# 1       77.813237  2022-03-25        3        1        2     0            165
# 2       77.688400  2022-03-19        2        2        1     3            130
# 3       77.026494  2022-04-05        4        3        1     0            105
# 4       80.289982  2022-03-26        0        0        2     0            150
#
#       Category
# 0     Clothing
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Category',axis=1)
y = df['Category']

# %%
df = df.drop('Order_Date',axis=1)

# %%
df.shape
# Out:
# (43739, 12)

# %%
df.isnull().sum()
# Out:
# Agent_Age           0
# Agent_Rating       54
# Store_Latitude      0
# Store_Longitude     0
# Drop_Latitude       0
# Drop_Longitude      0
# Weather             0
# Traffic             0
# Vehicle             0
# Area                0
# Delivery_Time       0
# Category            0
# dtype: int64

# %%
df['Agent_Rating'] = df['Agent_Rating'].fillna(df['Agent_Rating'].median())

# %%
df.isnull().sum()
# Out:
# Agent_Age          0
# Agent_Rating       0
# Store_Latitude     0
# Store_Longitude    0
# Drop_Latitude      0
# Drop_Longitude     0
# Weather            0
# Traffic            0
# Vehicle            0
# Area               0
# Delivery_Time      0
# Category           0
# dtype: int64

# %%
plt.figure(figsize=(10,7))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", square=True, cbar_kws={'shrink':0.8})
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
pair_subset = ["Agent_Age", "Agent_Rating", "Delivery_Time", "Store_Latitude", "Store_Longitude"]
sns.pairplot(df[pair_subset + ["Traffic"]], hue="Traffic", diag_kind="kde", corner=True, plot_kws={'alpha':0.6})
plt.suptitle("Pairwise Relationships", y=1.02)
plt.show()
# Out:
# C:\Users\CHINMAY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CHINMAY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\CHINMAY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
